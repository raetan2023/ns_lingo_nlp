# %%
import requests
import praw
import bs4
import nltk
import dotenv

import transformers
import torch
import accelerate

print("requests ok")
print("praw ok")
print("beautifulsoup4 ok")
print("nltk ok")
print("python-dotenv ok")
print("transformers ok")
print("torch ok")
print("accelerate ok")

print("all imports ok")
# Out:
# all imports ok
